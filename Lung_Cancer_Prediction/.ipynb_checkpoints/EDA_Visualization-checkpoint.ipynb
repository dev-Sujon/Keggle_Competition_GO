# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')
import os

# %%
df = pd.read_csv('df_encoded.csv')

# %%
## Unique Values (Categorical/Ordinal Insight)
for col in df.columns:
    display(f"{col}: {df[col].unique()}")
# Out:
# 'age: [ 64  50  65  51  37  49  56  48  47  67  45  46  21  62  60  57  36  61\n  71  74  35  54  44  68  59  58  63  69  70  52  40  78  75  72  42  53\n  39  66  41  43  55  38  30  34  76  73  80  31  85  28  79  87  77  33\n  32  25  90  84  81  27  82  83  22  86  26  93  29  23  19  24  89  18\n  91  95  88  20  94 101  15  92  16  17  10  14  99  13  97   9  12  98\n   7  96   4 104   8]'
# 'gender: [1 0]'
# 'country: [26 19 12  1 17 14  3  6 18 10 20 13 22 25 11  7  4  9 24 15 21  0  5  8\n 16 23  2]'
# 'cancer_stage: [0 2 3 1]'
# 'family_history: [1 0]'
# 'smoking_status: [3 1 2 0]'
# ...

# %%
df['survived'].value_counts(normalize=True)
# Out:
# survived
# 0    0.779771
# 1    0.220229
# Name: proportion, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
df.hist(figsize=(15,10), bins=10)
plt.tight_layout()
plt.show()

# %%
for col in ['age', 'bmi', 'cholesterol_level', 'treatment_duration_days']:
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
df.groupby('cancer_stage')['survived'].mean()
# Out:
# cancer_stage
# 0    0.218133
# 1    0.220891
# 2    0.220527
# 3    0.221366
# Name: survived, dtype: float64

# %%
df['gender'] = df['gender'].map({0: 'Female', 1: 'Male'})
# Repeat for others as needed

# %%
df
# Out:
#         age  gender  country  cancer_stage  family_history  smoking_status  \
# 0        64    Male       26             0               1               3
# 1        50  Female       19             2               1               3
# 2        65  Female       12             2               1               1
# 3        51  Female        1             0               0               3
# 4        37    Male       17             0               0               3
# ...     ...     ...      ...           ...             ...             ...
# 889995   40    Male       18             3               0               3
# 889996   62  Female        4             1               1               1
# 889997   48  Female        7             2               1               2
# 889998   67  Female       23             3               1               1
# 889999   55  Female       18             1               1               0
#
#          bmi  cholesterol_level  hypertension  asthma  cirrhosis  \
# ...
